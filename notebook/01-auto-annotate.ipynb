# %%
# !nvidia-smi
# Out:
# Sat Feb 28 05:41:23 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.105.08             Driver Version: 580.105.08     CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   48C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
from kaggle_secrets import UserSecretsClient

secret_name = "GITHUB_TOKEN" 

try:
    user_secrets = UserSecretsClient()
    personal_token = user_secrets.get_secret(secret_name)
    repo_address = "github.com/fazrigading/palmOilFruitCounting"
    # !git clone https://{personal_token}@{repo_address}
    
    print(f"Repository cloned successfully into the working directory!")

except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Cloning into 'palmOilFruitCounting'...
# remote: Enumerating objects: 214, done.
# remote: Counting objects: 100% (214/214), done.
# remote: Compressing objects: 100% (149/149), done.
# remote: Total 214 (delta 97), reused 169 (delta 57), pack-reused 0 (from 0)
# Receiving objects: 100% (214/214), 89.52 KiB | 3.20 MiB/s, done.
# Resolving deltas: 100% (97/97), done.
# Repository cloned successfully into the working directory!

# %%
# %cd palmOilFruitCounting/
# Out:
# /kaggle/working/palmOilFruitCounting

# %%
# !ls
# Out:
# AGENTS.md	 dataset	 pyproject.toml  src
# configs		 LICENSE	 README.md	 SUGGESTIONS.md
# CONTRIBUTING.md  MASTER-PLAN.md  scripts	 tests

# %%
# !git clone --depth 1 https://github.com/facebookresearch/sam2.git
# Out:
# fatal: destination path 'sam2' already exists and is not an empty directory.

# %%
# !cd sam2 && pip install -e .
# Out:
# Obtaining file:///kaggle/working/palmOilFruitCounting/sam2
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 1.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 6.8 MB/s eta 0:00:00
# ...
#   Building editable for SAM-2 (pyproject.toml) ... done
#   Created wheel for SAM-2: filename=sam_2-1.0-0.editable-cp312-cp312-linux_x86_64.whl size=13868 sha256=ae7c0bdbd2d97e5df128e41f89c2e8eca3b87b9691e5a2587cf6f2570c6385d3
#   Stored in directory: /tmp/pip-ephem-wheel-cache-5vytreyi/wheels/b8/f1/a4/7db66b50aba903d27f223b4da0a3deb4fa95e65876d49c01fe
# ...
#   Created wheel for iopath: filename=iopath-0.1.10-py3-none-any.whl size=31527 sha256=a70e30658b2ba872dc541be87b2605ce13610060df5c6d8bc1e87d25e2bccc06
# ...

# %%
# !pip install -e .
# Out:
# Obtaining file:///kaggle/working/palmOilFruitCounting
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for palm-oil-counting (pyproject.toml) ... done
#   Created wheel for palm-oil-counting: filename=palm_oil_counting-1.0.0-0.editable-py3-none-any.whl size=4403 sha256=a0a25fb0b54318bd578968fa225c2b89e442709b43b7e28f261a3a2036eb34de
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ey4qi_jo/wheels/89/f1/c4/05f9c9520c58c204b83ce5f96aa3952432485e6625d4778032
# Successfully built palm-oil-counting
# ...

# %%
# !dir ../palmOilFruitCounting-backup/
# Out:
# augment.py	   LICENSE		 sam2_hiera_tiny.pt
# cropper_plan.md    plan.md		 sam2_hiera_t.yaml
# cropper.py	   README.md		 sam_annotations.zip
# dataAnnotation.py  requirements.txt	 sam_annotator.py
# dataset		   sam2.1_hiera_tiny.pt  version_info.txt
# GEMINI.md	   sam2.1_hiera_t.yaml	 visualize_annotations.py

# %%
# !python scripts/annotate.py sam --input dataset/images/ --output dataset/sam_annotate_baseplus/ --model-type base_plus --device cuda
# Out:
# Using default checkpoint: sam2_hiera_base_plus.pt
# Loading SAM2 model (base_plus) from sam2_hiera_base_plus.pt on cuda...
# Found 539 images. Starting automatic annotation...
#   0%|                                                   | 0/539 [00:00<?, ?it/s]/kaggle/working/palmOilFruitCounting/sam2/sam2/sam2_image_predictor.py:431: UserWarning: /kaggle/working/palmOilFruitCounting/sam2/sam2/_C.so: undefined symbol: _ZNK3c1010TensorImpl15incref_pyobjectEv
#
# Skipping the post-processing step due to the error above. You can still use SAM 2 and it's OK to ignore the error above, although some post-processing functionality may be limited (which doesn't affect the results in most cases; see https://github.com/facebookresearch/sam2/blob/main/INSTALL.md).
#   masks = self._transforms.postprocess_masks(
#  87%|█████████████████████████████████▉     | 469/539 [1:32:19<13:48, 11.83s/it]

# %% [markdown]
# ## try 2

# %%
# %cd palmOilFruitCounting/
# Out:
# /kaggle/working/palmOilFruitCounting

# %%
# !cd sam2 && pip install -e ".[notebooks]"
# Out:
# Obtaining file:///kaggle/working/palmOilFruitCounting/sam2
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.6/13.6 MB 75.8 MB/s eta 0:00:00:00:010:01
# ...
#   Building editable for SAM-2 (pyproject.toml) ... done
#   Created wheel for SAM-2: filename=sam_2-1.0-0.editable-cp312-cp312-linux_x86_64.whl size=13868 sha256=b0e2f2096e7a18999f74696b35adfdb11023c9df5423dda7fe11e38c50723333
#   Stored in directory: /tmp/pip-ephem-wheel-cache-d8okeu4i/wheels/b8/f1/a4/7db66b50aba903d27f223b4da0a3deb4fa95e65876d49c01fe
# Successfully built SAM-2
# ...
#   Attempting uninstall: SAM-2
#     Found existing installation: SAM-2 1.0
#     Uninstalling SAM-2-1.0:
#       Successfully uninstalled SAM-2-1.0
# ...

# %%
# !pip install -e .
# Out:
# Obtaining file:///kaggle/working/palmOilFruitCounting
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for palm-oil-counting (pyproject.toml) ... done
#   Created wheel for palm-oil-counting: filename=palm_oil_counting-1.0.0-0.editable-py3-none-any.whl size=4403 sha256=0dd7081982248337718ba29a960179b33153d61925054cb50e9f8f9fa45bdc7c
#   Stored in directory: /tmp/pip-ephem-wheel-cache-4u809v3b/wheels/89/f1/c4/05f9c9520c58c204b83ce5f96aa3952432485e6625d4778032
# Successfully built palm-oil-counting
# ...
#   Attempting uninstall: palm-oil-counting
#     Found existing installation: palm-oil-counting 1.0.0
#     Uninstalling palm-oil-counting-1.0.0:
#       Successfully uninstalled palm-oil-counting-1.0.0
# ...

# %%
# !cp -r dataset/sam_annotate_baseplus/ dataset/sam_annotate_baseplus2/

# %%
import shutil
from pathlib import Path

IMAGES_DIR = Path("dataset/images")
IMAGES2_DIR = Path("dataset/images2")

START_INDEX = 469
END_INDEX = 539

IMAGES2_DIR.mkdir(exist_ok=True)

image_files = sorted(IMAGES_DIR.glob("*.jpg"))

for i in range(START_INDEX - 1, END_INDEX):
    src = image_files[i]
    dst = IMAGES2_DIR / src.name
    shutil.copy2(src, dst)
    print(f"Copied: {src.name}")
# Out:
# Copied: IMG_20250626_173023.jpg
# Copied: IMG_20250626_173033.jpg
# Copied: IMG_20250626_173044.jpg
# Copied: IMG_20250626_173104.jpg
# Copied: IMG_20250626_173106.jpg
# Copied: IMG_20250626_173108.jpg
# Copied: IMG_20250626_173115.jpg
# Copied: IMG_20250626_173125.jpg
# Copied: IMG_20250626_173128.jpg
# Copied: IMG_20250626_173132.jpg
# Copied: IMG_20250626_173134.jpg
# Copied: IMG_20250626_173137.jpg
# Copied: IMG_20250626_173212.jpg
# Copied: IMG_20250626_173214.jpg
# Copied: IMG_20250626_173215.jpg
# Copied: IMG_20250626_173218.jpg
# Copied: IMG_20250626_173222.jpg
# Copied: IMG_20250626_173225.jpg
# Copied: IMG_20250626_173237.jpg
# Copied: IMG_20250626_173239.jpg
# Copied: IMG_20250626_173249.jpg
# Copied: IMG_20250626_173252.jpg
# Copied: IMG_20250626_173254.jpg
# Copied: IMG_20250626_173301.jpg
# Copied: IMG_20250626_173923.jpg
# Copied: IMG_20250626_173925.jpg
# Copied: IMG_20250626_173927.jpg
# Copied: IMG_20250626_173929.jpg
# Copied: IMG_20250626_173931.jpg
# ...

# %%
# !python scripts/annotate.py sam --input dataset/images2/ --output dataset/sam_annotate_baseplus_sisa/ --model-type base_plus --device cuda
# Out:
# Using default checkpoint: sam2_hiera_base_plus.pt
# Loading SAM2 model (base_plus) from sam2_hiera_base_plus.pt on cuda...
# Found 71 images. Starting automatic annotation...
#   0%|                                                    | 0/71 [00:00<?, ?it/s]/kaggle/working/palmOilFruitCounting/sam2/sam2/sam2_image_predictor.py:431: UserWarning: /kaggle/working/palmOilFruitCounting/sam2/sam2/_C.so: undefined symbol: _ZNK3c1010TensorImpl15incref_pyobjectEv
#
# Skipping the post-processing step due to the error above. You can still use SAM 2 and it's OK to ignore the error above, although some post-processing functionality may be limited (which doesn't affect the results in most cases; see https://github.com/facebookresearch/sam2/blob/main/INSTALL.md).
#   masks = self._transforms.postprocess_masks(
# 100%|███████████████████████████████████████████| 71/71 [13:55<00:00, 11.77s/it]

# %%
# !zip -r sam_annotate-part1.zip dataset/sam_annotate_baseplus2
# !zip -r sam_annotate-part2.zip dataset/sam_annotate_baseplus_sisa
# Out:
#   adding: dataset/sam_annotate_baseplus2/ (stored 0%)
#   adding: dataset/sam_annotate_baseplus2/labels_seg/ (stored 0%)
#   adding: dataset/sam_annotate_baseplus2/labels_seg/IMG_20250622_165954.txt (deflated 79%)
#   adding: dataset/sam_annotate_baseplus2/labels_seg/IMG_20250613_173752.txt (deflated 79%)
#   adding: dataset/sam_annotate_baseplus2/labels_seg/IMG_20250622_171008.txt (deflated 80%)
#   adding: dataset/sam_annotate_baseplus2/labels_seg/IMG_20250626_172350_1.txt (deflated 80%)
#   adding: dataset/sam_annotate_baseplus2/labels_seg/IMG_20250622_171210.txt (deflated 80%)
#   adding: dataset/sam_annotate_baseplus2/labels_seg/IMG_20250626_173923.txt (deflated 80%)
#   adding: dataset/sam_annotate_baseplus2/labels_seg/IMG_20250626_173115.txt (deflated 80%)
#   adding: dataset/sam_annotate_baseplus2/labels_seg/IMG_20250622_170720.txt (deflated 80%)
#   adding: dataset/sam_annotate_baseplus2/labels_seg/IMG_20250623_172547.txt (deflated 80%)
# ...
